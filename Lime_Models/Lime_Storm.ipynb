# %%
import keras
import nltk
import pandas as pd
import numpy as np
import re
import io
import matplotlib
from IPython.display import display
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# !gdown --id 1ti6QbZh_j9rh9fhKGZIoThM7FN9tF3Un #training data
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1ti6QbZh_j9rh9fhKGZIoThM7FN9tF3Un
# To: /content/labeled_data.csv
# 100% 2.57M/2.57M [00:00<00:00, 133MB/s]

# %%
tweets = pd.read_csv('/content/stormfront.csv')
tweets['label'] = tweets['label'].replace({'hate': 0})
tweets['label'] = tweets['label'].replace({'noHate': 1})
tweets['label'] = tweets['label'].replace({'relation': 1})
tweets['label'] = tweets['label'].replace({'idk/skip': 1})
dicti = { 'label': 'class','tweet': 'tweet'}
tweets.rename(columns=dicti,
          inplace=True)
display(tweets.groupby("class").count())
# Out:
#        Unnamed: 0  file_id  tweet
# class
# 0            1196     1196   1196
# 1            9748     9748   9748

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
nltk.download('punkt')
ps = PorterStemmer()
for i in range(len(tweets)):
  words = word_tokenize(tweets['tweet'][i])
  for j in range(len(words)):
    words[j] = ps.stem(words[j]) if words[j] not in set(all_stopwords) else ''
  tweets['tweet'][i] = ' '.join(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
display(tweets.head())
# Out:
#    Unnamed: 0     file_id  class  \
# 0           0  12834217_1      1
# 1           1  12834217_2      1
# 2           2  12834217_3      1
# 3           3  12834217_4      0
# 4           4  12834217_5      1
#
#                                                tweet
# 0  [ 'a  march 13th , 2014 ,  booklet   download ...
# 1  [ 'in order  help increas  booklet download , ...
# 2  [ ' ( simpli copi  past  follow text   youtub ...
# 3  [ 'click    free download   color illustr 132 ...
# 4  [ `` click   `` download ( 7.42 mb ) `` green ...

# %%
def clean_text(df, text_field):
    df[text_field] = df[text_field].str.replace(r"http\S+", "") # remove URL protocol with trailing whitespace
    df[text_field] = df[text_field].str.replace(r"http", "") # remove URL protocol
    df[text_field] = df[text_field].str.replace(r"@\S+", "") # remove at signs with leading spaces 
    df[text_field] = df[text_field].str.replace(r"[^A-Za-z0-9(),!?@\'\`\"\n]", " ") # remove non-alphanumerical
    df[text_field] = df[text_field].str.replace(r"@", "at") # replace at signs with "at"
    df[text_field] = df[text_field].str.replace(r'\b\w{1,3}\b', '') # replace at words
    df[text_field] = df[text_field].str.replace(r'[0-9]', '') # replace at words
    df[text_field] = df[text_field].str.lower() # convert all to lowercase
    # df[text_field] = df[text_field].apply(lambda x: ''.join([stemmer.stem(y) for y in x]))
    return df

# %%
# from nltk.stem import PorterStemmer
# from nltk.tokenize import word_tokenize
# w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
# lemmatizer = nltk.stem.WordNetLemmatizer()
# nltk.download('wordnet')
# nltk.download('omw-1.4')
# ps = PorterStemmer()
# def cleann(df,text_field):
#   df[text_field] = df[text_field].apply(lambda x: ''.join([ps.stem(y) for y in x]))
#   # xp = pd.DataFrame(df[text_field], columns=[text_field])
#   # df[text_field] = xp.text_field.apply([lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text_field)])
#   return df

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# function to transform tweets to vectorized bag of word embedding
def vectorizer(data):
    count_vectorizer = CountVectorizer()

    emb = count_vectorizer.fit_transform(data)

    return emb, count_vectorizer

# set of all tweet text
# list_corpus = tweets["tweet"]
list_corpus = tweets[['class', 'tweet']]
# set of all tweet class labels
list_labels = tweets["class"].tolist()

# split into 80/20 train/test 
X_train, X_test, y_train, y_test = train_test_split(list_corpus, list_labels, test_size=0.2, random_state=69)

X_train = clean_text(X_train, "tweet")
# print(X_train)
# # X_train = cleann(X_train,'tweet')
# print(X_train)

# convert training and test set word to bag of words vectorized representation
X_train_counts, count_vectorizer = vectorizer(X_train['tweet'])
X_test_counts = count_vectorizer.transform(X_test['tweet'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
from sklearn.linear_model import LogisticRegression

# define logistic regression model 
clf = LogisticRegression()

# fit model on training data
clf.fit(X_train_counts, y_train)

# get model predictions on bag of words vectorized test data
y_predicted_counts = clf.predict(X_test_counts)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred_np = clf.predict(X_test_counts)
cm = confusion_matrix(y_test, y_pred_np)
print(classification_report(y_test,y_pred_np))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.25      0.34       240
#            1       0.91      0.98      0.94      1949
#
#     accuracy                           0.90      2189
#    macro avg       0.74      0.61      0.64      2189
# weighted avg       0.88      0.90      0.88      2189

# %%
def get_most_important_features(vectorizer, coefficients, n=20):
    
    # convert index of word from vectorizer into the word 
    index_to_word = {index:word for word,index in count_vectorizer.vocabulary_.items()}
    
    # assign coefficient to word by matching the index of the coefficient and word
    word_importances = [(coef, index_to_word[index]) for index, coef in enumerate(clf.coef_[0])]
    sorted_coeff = sorted(word_importances, key = lambda x : x[0], reverse=True)
    # n = len(word_importances)//2
    # print(word_importances)
    p = []
    n = 0
    for x,y in sorted_coeff:
      if(x>=0):
        n+=1
      p.append(y)
    print(p)
    print(n)
    top = sorted(sorted_coeff[:20], key = lambda x : x)
    print(sorted_coeff[:n])
    print([y for x,y in sorted_coeff[:n]])

    print(len(set(word_importances)))
    bottom = sorted_coeff[-20:]
    print(sorted_coeff[n:])
    p= [y for x,y in sorted_coeff[n:]]
    print(p[::-1])
    print(len(p))
    classes = {
        'top':top,
        'bottom':bottom
        }
    return classes

importance = get_most_important_features(count_vectorizer, clf.coef_)
# Out:
# ['lynch', 'band', 'water', 'facebook', 'hair', 'youtub', 'meet', 'nationalist', 'happi', 'though', 'evid', 'taught', 'dont', 'thread', 'view', 'footbal', 'figur', 'seen', 'reach', 'main', 'organ', 'type', 'student', 'father', 'past', 'televis', 'hurt', 'rich', 'what', 'conserv', 'ladi', 'ignor', 'talk', 'fight', 'king', 'group', 'four', 'join', 'suspect', 'york', 'smart', 'church', 'miss', 'base', 'muscl', 'preserv', 'section', 'friend', 'intellig', 'integr', 'week', 'teenag', 'song', 'citizen', 'goinna', 'recon', 'incid', 'post', 'state', 'soldier', 'five', 'research', 'strang', 'sorri', 'certain', 'idea', 'rememb', 'zero', 'languag', 'privat', 'defens', 'counti', 'famili', 'scroung', 'name', 'identifi', 'pride', 'from', 'polit', 'stronger', 'includ', 'earli', 'near', 'link', 'duke', 'year', 'clear', 'onlin', 'mostli', 'unsuspect', 'nice', 'focu', 'protect', 'asia', 'accord', 'encourag', 'australia', 'film', 'burger', 'buck', 'sourc', 'greek', 'sport', 'gypsi', 'scottish', 'celebr', 'common', 'canadian', 'proud', 'direct', 'after', 'bibl', 'nordic', 'poster', 'ancient', 'pressur', 'rebel', 'definit', 'design', 'stat', 'almost', 'fill', 'lighter', 'inform', 'floor', 'attent', 'ship', 'american', 'birth', 'experi', 'thank', 'month', 'wide', 'australian', 'unit', 'copi', 'manag', 'among', 'younger', 'choic', 'shirt', 'thursday', 'paradis', 'will', 'class', 'actual', 'virtual', 'teen', 'prepar', 'relat', 'deliber', 'subject', 'stabl', 'line', 'site', 'sleep', 'shed', 'utopian', 'stori', 'bought', 'finish', 'park', 'speak', 'internet', 'chat', 'anmigrants', 'europeandailynews', 'catch', 'scene', 'teacher', 'event', 'happili', 'histor', 'read', 'nuclear', 'kiss', 'first', 'hour', 'neighborhood', 'relax', 'topic', 'minist', 'pair', 'muenster', 'wear', 'should', 'nativ', 'prosecut', 'grow', 'also', 'bigot', 'lesson', 'cool', 'troubl', 'advanc', 'commun', 'shot', 'pictur', 'visit', 'chinaman', 'employe', 'pure', 'right', 'write', 'room', 'along', 'march', 'book', 'afraid', 'driver', 'justin', 'provid', 'elderli', 'record', 'situat', 'phone', 'symbiosi', 'special', 'html', 'moon', 'sign', 'ought', 'weekend', 'full', 'final', 'klan', 'flip', 'januari', 'polici', 'chang', 'newsroom', 'cigarett', 'speech', 'hybrid', 'forward', 'resid', 'valu', 'kuzmin', 'western', 'fish', 'statement', 'compani', 'upset', 'agent', 'edit', 'beat', 'youtube', 'texa', 'britain', 'morn', 'program', 'board', 'account', 'here', 'multi', 'question', 'technolog', 'emerg', 'fire', 'arriv', 'seri', 'theori', 'leader', 'belfri', 'lygin', 'rink', 'skating', 'elementari', 'vancouv', 'basketbal', 'capit', 'california', 'easier', 'attach', 'confeder', 'vomit', 'advic', 'store', 'condit', 'presid', 'hide', 'northern', 'track', 'break', 'cross', 'scandinavian', 'crack', 'liter', 'instil', 'wood', 'moment', 'closur', 'blog', 'potenti', 'talentless', 'untal', 'wall', 'christma', 'slavic', 'lead', 'pyre', 'spray', 'ralli', 'labor', 'vike', 'particular', 'mine', 'trump', 'short', 'belief', 'perfectli', 'irishcentr', 'percent', 'sapien', 'owner', 'sometim', 'slogan', 'team', 'translat', 'cost', 'outsid', 'tonight', 'econom', 'face', 'dougla', 'beauti', 'school', 'front', 'gover', 'standard', 'pakistani', 'season', 'bankrol', 'inspector', 'celtic', 'steel', 'miscegen', 'celt', 'argu', 'exclus', 'almighti', 'shave', 'incom', 'clap', 'photo', 'media', 'columbu', 'featur', 'updat', 'grandfath', 'earn', 'tend', 'rock', 'martial', 'sound', 'begin', 'entertain', 'japanes', 'oppon', 'alon', 'anti', 'simpli', 'lord', 'bulgaria', 'strangl', 'paedophilia', 'terror', 'love', 'reich', 'norway', 'chicago', 'abil', 'violenc', 'economi', 'throw', 'demograph', 'alot', 'everyday', 'district', 'southern', 'alcohol', 'completli', 'hard', 'fever', 'censu', 'ranger', 'nonsens', 'parole', 'against', 'death', 'quickli', 'accomod', 'cloth', 'christoph', 'slut', 'note', 'steve', 'hung', 'curiou', 'merci', 'three', 'whole', 'easili', 'maniac', 'swiss', 'revers', 'patrol', 'weapon', 'appli', 'charg', 'pro ...
# 7208
# [(1.137576803046437, 'lynch'), (1.1274027516283367, 'band'), (1.1139223545583314, 'water'), (1.0753431013840924, 'facebook'), (1.036815470272031, 'hair'), (1.024758556088471, 'youtub'), (1.0041260572198547, 'meet'), (0.9918803299513838, 'nationalist'), (0.9866380880536368, 'happi'), (0.9828300001063514, 'though'), (0.9729486221162005, 'evid'), (0.9384329066145387, 'taught'), (0.9201445907760962, 'dont'), (0.9166713571917516, 'thread'), (0.9021912794458186, 'view'), (0.8920341075337292, 'footbal'), (0.8913697924315862, 'figur'), (0.8879828554850737, 'seen'), (0.8876523868932349, 'reach'), (0.8860871597181266, 'main'), (0.8828747623780516, 'organ'), (0.8700885269988461, 'type'), (0.8663822041685322, 'student'), (0.8606484700914957, 'father'), (0.8526036242017181, 'past'), (0.8495897553690545, 'televis'), (0.8437734302507234, 'hurt'), (0.8432337523433674, 'rich'), (0.8372943937605892, 'what'), (0.7998416426142341, 'conserv'), (0.7888729403397414, 'ladi'), (0.7840279202160169, 'ignor'), (0.7817115123855699, 'talk'), (0.7811473740881155, 'fight'), (0.7781361215911226, 'king'), (0.7721243149561712, 'group'), (0.7708291202827007, 'four'), (0.7664283274644973, 'join'), (0.7656214870180186, 'suspect'), (0.7593341130798602, 'york'), (0.7525511265574134, 'smart'), (0.7488653931510547, 'church'), (0.7463460777144797, 'miss'), (0.738019073646205, 'base'), (0.7328611465976572, 'muscl'), (0.730791223609308, 'preserv'), (0.7293849886424223, 'section'), (0.7222665240130299, 'friend'), (0.7200234050392228, 'intellig'), (0.7161081743609237, 'integr'), (0.7159624735829488, 'week'), (0.7129544547927902, 'teenag'), (0.7125190785921827, 'song'), (0.7099593683156848, 'citizen'), (0.709625990451131, 'goinna'), (0.709625990451131, 'recon'), (0.7061427328739188, 'incid'), (0.7044311574642333, 'post'), (0.7040266185613777, 'state'), (0.7019859171861482, 'soldier'), (0.7017467049118489, 'five'), (0.7008888311664783, 'research'), (0.6998103873392395, 'strang'), (0.6979318119025074, 'sorri'), (0.6951743761766573, 'certain'), (0.6940142315567367, 'idea'), (0.6936438288667058, 'rememb'), (0.6929041081555865, 'zero'), (0.6832468569619295, 'languag'), (0.6832060432170245, 'privat'), (0.6823161216341043, 'defens'), (0.6816588316744632, 'counti'), (0.6794011525643406, 'famili'), (0.6768979516761625, 'scroung'), (0.6754966131775025, 'name'), (0.6753077004811912, 'identifi'), (0.6719006852813223, 'pride'), (0.6672886321119599, 'from'), (0.6664043032288045, 'polit'), (0.6659101204091727, 'stronger'), (0.6642947166226785, 'includ'), (0.6633395203216267, 'earli'), (0.6614548197910766, 'near'), (0.6536171690500037, 'link'), (0.6481564572375568, 'duke'), (0.6473708075421842, 'year'), (0.6464112950255918, 'clear'), (0.6439992545392019, 'onlin'), (0.6429104817325366, 'mostli'), (0.639203960020975, 'unsuspect'), (0.6380227010584766, 'nice'), (0.6362754957345578, 'focu'), (0.6362577428867333, 'protect'), (0.6337436195610221, 'asia'), (0.6325983813778566, 'accord'), (0.630425405510134, 'encourag'), (0.6287253946185739, 'australia'), (0.6252673823345907, 'film'), (0.6236506244510511, 'burger'), (0.6230743254005289, 'buck'), (0.6199880198363045, 'sourc'), (0.615373697508804, 'greek'), (0.6150872692816969, 'sport'), (0.6120548944039913, 'gypsi'), (0.6109900507340129, 'scottish'), (0.6089795545020631, 'celebr'), (0.6050532667642944, 'common'), (0.6034055559220166, 'canadian'), (0.6030420108969169, 'proud'), (0.6009585575266287, 'direct'), (0.5991975300461375, 'after'), (0.5990182872357593, 'bibl'), (0.5975176554293319, 'nordic'), (0.5960103409296523, 'poster'), (0.5955288181249644, 'ancient'), (0.5938760503928515, 'pressur'), (0.5910755529665634, 'rebel'), (0.5881229146636568, 'definit'), (0.5843471690200659, 'design'), (0.5839847036268556, 'stat'), (0.5807473888927688, 'almost'), (0.5805136194348618, 'fill'), (0.5742070127295397, 'lighter'), (0.569071522642974, 'inform'), (0.5687775302114455, 'floor'), (0.5681774311648209, 'attent'), (0.5681746298526792, 'ship'), (0.56817010935 ...
# ['lynch', 'band', 'water', 'facebook', 'hair', 'youtub', 'meet', 'nationalist', 'happi', 'though', 'evid', 'taught', 'dont', 'thread', 'view', 'footbal', 'figur', 'seen', 'reach', 'main', 'organ', 'type', 'student', 'father', 'past', 'televis', 'hurt', 'rich', 'what', 'conserv', 'ladi', 'ignor', 'talk', 'fight', 'king', 'group', 'four', 'join', 'suspect', 'york', 'smart', 'church', 'miss', 'base', 'muscl', 'preserv', 'section', 'friend', 'intellig', 'integr', 'week', 'teenag', 'song', 'citizen', 'goinna', 'recon', 'incid', 'post', 'state', 'soldier', 'five', 'research', 'strang', 'sorri', 'certain', 'idea', 'rememb', 'zero', 'languag', 'privat', 'defens', 'counti', 'famili', 'scroung', 'name', 'identifi', 'pride', 'from', 'polit', 'stronger', 'includ', 'earli', 'near', 'link', 'duke', 'year', 'clear', 'onlin', 'mostli', 'unsuspect', 'nice', 'focu', 'protect', 'asia', 'accord', 'encourag', 'australia', 'film', 'burger', 'buck', 'sourc', 'greek', 'sport', 'gypsi', 'scottish', 'celebr', 'common', 'canadian', 'proud', 'direct', 'after', 'bibl', 'nordic', 'poster', 'ancient', 'pressur', 'rebel', 'definit', 'design', 'stat', 'almost', 'fill', 'lighter', 'inform', 'floor', 'attent', 'ship', 'american', 'birth', 'experi', 'thank', 'month', 'wide', 'australian', 'unit', 'copi', 'manag', 'among', 'younger', 'choic', 'shirt', 'thursday', 'paradis', 'will', 'class', 'actual', 'virtual', 'teen', 'prepar', 'relat', 'deliber', 'subject', 'stabl', 'line', 'site', 'sleep', 'shed', 'utopian', 'stori', 'bought', 'finish', 'park', 'speak', 'internet', 'chat', 'anmigrants', 'europeandailynews', 'catch', 'scene', 'teacher', 'event', 'happili', 'histor', 'read', 'nuclear', 'kiss', 'first', 'hour', 'neighborhood', 'relax', 'topic', 'minist', 'pair', 'muenster', 'wear', 'should', 'nativ', 'prosecut', 'grow', 'also', 'bigot', 'lesson', 'cool', 'troubl', 'advanc', 'commun', 'shot', 'pictur', 'visit', 'chinaman', 'employe', 'pure', 'right', 'write', 'room', 'along', 'march', 'book', 'afraid', 'driver', 'justin', 'provid', 'elderli', 'record', 'situat', 'phone', 'symbiosi', 'special', 'html', 'moon', 'sign', 'ought', 'weekend', 'full', 'final', 'klan', 'flip', 'januari', 'polici', 'chang', 'newsroom', 'cigarett', 'speech', 'hybrid', 'forward', 'resid', 'valu', 'kuzmin', 'western', 'fish', 'statement', 'compani', 'upset', 'agent', 'edit', 'beat', 'youtube', 'texa', 'britain', 'morn', 'program', 'board', 'account', 'here', 'multi', 'question', 'technolog', 'emerg', 'fire', 'arriv', 'seri', 'theori', 'leader', 'belfri', 'lygin', 'rink', 'skating', 'elementari', 'vancouv', 'basketbal', 'capit', 'california', 'easier', 'attach', 'confeder', 'vomit', 'advic', 'store', 'condit', 'presid', 'hide', 'northern', 'track', 'break', 'cross', 'scandinavian', 'crack', 'liter', 'instil', 'wood', 'moment', 'closur', 'blog', 'potenti', 'talentless', 'untal', 'wall', 'christma', 'slavic', 'lead', 'pyre', 'spray', 'ralli', 'labor', 'vike', 'particular', 'mine', 'trump', 'short', 'belief', 'perfectli', 'irishcentr', 'percent', 'sapien', 'owner', 'sometim', 'slogan', 'team', 'translat', 'cost', 'outsid', 'tonight', 'econom', 'face', 'dougla', 'beauti', 'school', 'front', 'gover', 'standard', 'pakistani', 'season', 'bankrol', 'inspector', 'celtic', 'steel', 'miscegen', 'celt', 'argu', 'exclus', 'almighti', 'shave', 'incom', 'clap', 'photo', 'media', 'columbu', 'featur', 'updat', 'grandfath', 'earn', 'tend', 'rock', 'martial', 'sound', 'begin', 'entertain', 'japanes', 'oppon', 'alon', 'anti', 'simpli', 'lord', 'bulgaria', 'strangl', 'paedophilia', 'terror', 'love', 'reich', 'norway', 'chicago', 'abil', 'violenc', 'economi', 'throw', 'demograph', 'alot', 'everyday', 'district', 'southern', 'alcohol', 'completli', 'hard', 'fever', 'censu', 'ranger', 'nonsens', 'parole', 'against', 'death', 'quickli', 'accomod', 'cloth', 'christoph', 'slut', 'note', 'steve', 'hung', 'curiou', 'merci', 'three', 'whole', 'easili', 'maniac', 'swiss', 'revers', 'patrol', 'weapon', 'appli', 'charg', 'pro ...
# 9353
# [(-0.0004385981129818522, 'safe'), (-0.0005156734277166834, 'taint'), (-0.0005166915317156631, 'there'), (-0.0007015697417483652, 'subspeci'), (-0.000913363667580459, 'user'), (-0.0015956785252938502, 'recommend'), (-0.0016764784627451036, 'humanoid'), (-0.0016764784627451036, 'oddli'), (-0.002499894886188061, 'banana'), (-0.0028862559842886934, 'area'), (-0.003345396057920308, 'forth'), (-0.0035076661569416697, 'twice'), (-0.004128178593272686, 'rabid'), (-0.004437919569810212, 'storm'), (-0.004680587478240591, 'contrast'), (-0.004680587478240591, 'unfar'), (-0.0054047439072551304, 'toilet'), (-0.006093014361543523, 'verl'), (-0.006214545764836894, 'culture'), (-0.006370615787889919, 'rebuild'), (-0.006430313171678719, 'lard'), (-0.006578868132929606, 'messag'), (-0.007043572197436289, 'serb'), (-0.007065817826342639, 'soul'), (-0.007568009079048153, 'pull'), (-0.008208121491345659, 'jamican'), (-0.008476257751248318, 'funniest'), (-0.008599709282819123, 'attack'), (-0.00860422680262885, 'yesterday'), (-0.009315599781045718, 'archiv'), (-0.009388453694826418, 'influenc'), (-0.00946678526579014, 'health'), (-0.009982039393178075, 'reluct'), (-0.009982039393178075, 'terrifi'), (-0.009982039393178075, 'usal'), (-0.010525235254947392, 'becasu'), (-0.010525235254947392, 'bullsnot'), (-0.010525235254947392, 'miscegin'), (-0.010701543956207114, 'paid'), (-0.011400290614650387, 'didnt'), (-0.011431531576637339, 'window'), (-0.01168047503705443, 'slither'), (-0.012076772011099371, 'cloud'), (-0.012219796764635601, 'duti'), (-0.012439515034707934, 'game'), (-0.012917949080929629, 'scream'), (-0.01388901413276707, 'coupl'), (-0.014686374085150767, 'memo'), (-0.01471560493767278, 'weather'), (-0.015412840325262401, 'deviant'), (-0.015412840325262401, 'skulk'), (-0.016285234473697167, 'obamamania'), (-0.01661979647622212, 'contamin'), (-0.017383479122098398, 'multiculturist'), (-0.017656715629000258, 'jewtub'), (-0.01779396792707136, 'prevent'), (-0.01873769028898997, 'extinct'), (-0.018819449582790047, 'sleipnir'), (-0.019343697613065088, 'skill'), (-0.020236353942088815, 'dice'), (-0.020236353942088815, 'watermelon'), (-0.02144297134595714, 'close'), (-0.02160715624050279, 'fella'), (-0.022570040906951937, 'doom'), (-0.022873131448669013, 'extent'), (-0.023623215002649387, 'teem'), (-0.02366171918497709, 'wore'), (-0.023986063412891626, 'ghettobraggingrights'), (-0.023986063412891626, 'wordpress'), (-0.024196481194344973, 'neichzch'), (-0.02426982584480884, 'toward'), (-0.024692515207870934, 'favor'), (-0.024765731983758855, 'know'), (-0.02483922029346547, 'otherwis'), (-0.025510693127480114, 'backward'), (-0.026271747025826186, 'essay'), (-0.02651824026303818, 'sieg'), (-0.026936112841240586, 'report'), (-0.027933272481451173, 'properti'), (-0.027958746532268035, 'humor'), (-0.028075056510010327, 'adolesc'), (-0.02813366303047171, 'mindless'), (-0.028202882086966828, 'enrich'), (-0.02877266533476496, 'befriend'), (-0.02877266533476496, 'irika'), (-0.02877266533476496, 'localtv'), (-0.02877266533476496, 'pensacola'), (-0.02877266533476496, 'sargent'), (-0.02877266533476496, 'spearchuck'), (-0.029064704460919962, 'save'), (-0.029147923749275627, 'empir'), (-0.029236228919505638, 'sectarian'), (-0.029709644809885406, 'greatli'), (-0.029709644809885406, 'prop'), (-0.029818870293503632, 'taken'), (-0.030381349319355933, 'hitler'), (-0.03055636034467315, 'bread'), (-0.030760498948070696, 'foriegn'), (-0.030760498948070696, 'payments'), (-0.030760498948070696, 'tellyspeopl'), (-0.030830861660795645, 'scienc'), (-0.030923381642576613, 'david'), (-0.03099763946676737, 'news'), (-0.03157996063314028, 'grandmoth'), (-0.031755081322089124, 'admir'), (-0.03194828419449964, 'perhap'), (-0.03236223904779824, 'thin'), (-0.032446089499151766, 'togeth'), (-0.03281186862525872, 'sinc'), (-0.03289321271249216, 'yule'), (-0.032940419736553726, 'angri'), (-0.03322675347268235, 'sell'), (-0.03348097317667126, 'stalk'), (-0.03353300956898978, 'justifi'), (-0. ...
# ['scum', 'libtard', 'groid', 'negro', 'monkey', 'deport', 'chimp', 'homosexu', 'filth', 'liber', 'beast', 'holohoax', 'coon', 'zionist', 'creatur', 'infect', 'filthi', 'threat', 'shop', 'savag', 'holocaust', 'islam', 'hoax', 'starv', 'civil', 'evil', 'everywher', 'useless', 'cesspool', 'therefor', 'cure', 'crippin', 'paki', 'repres', 'their', 'jungl', 'negroid', 'mouth', 'naiv', 'wipe', 'primit', 'creep', 'guilt', 'infest', 'gorilla', 'mexican', 'mudd', 'jewish', 'they', 'nigga', 'parad', 'charad', 'lust', 'mestizo', 'homo', 'anger', 'disgust', 'produc', 'daughter', 'raci', 'worst', 'rainbow', 'hell', 'spic', 'vile', 'drown', 'puppet', 'niglet', 'goyim', 'suck', 'noos', 'africa', 'kosher', 'invas', 'might', 'becaus', 'destruct', 'dublin', 'kick', 'swede', 'mongrel', 'traitor', 'sick', 'killer', 'push', 'crap', 'breed', 'whit', 'muslim', 'indigen', 'freedom', 'chosen', 'hungarian', 'smell', 'lefti', 'soon', 'pool', 'pollut', 'kaffir', 'wisdom', 'outfit', 'feed', 'thick', 'assum', 'jump', 'space', 'diablo', 'dirt', 'fool', 'flood', 'rabbi', 'oppos', 'promis', 'known', 'trash', 'cohes', 'concern', 'harm', 'stone', 'belong', 'leav', 'depend', 'hypocrit', 'advantag', 'forgiv', 'perfect', 'dear', 'chimpout', 'paedophil', 'bleach', 'black', 'marxist', 'unfortun', 'pile', 'threaten', 'kingston', 'slag', 'primat', 'yeah', 'madex', 'poison', 'destroy', 'hire', 'evolv', 'nowaday', 'talmudivis', 'propaganda', 'vermin', 'expect', 'slowli', 'lesbian', 'african', 'defend', 'societi', 'detriment', 'behav', 'tourist', 'invad', 'aren', 'dievers', 'dung', 'string', 'kept', 'truth', 'recruit', 'degeneraci', 'ethnic', 'doubt', 'indian', 'rape', 'nigeria', 'yellow', 'worthless', 'ukrain', 'sheboon', 'disgrac', 'butcher', 'gestur', 'worlder', 'risk', 'bless', 'human', 'anim', 'desir', 'suppos', 'prison', 'prostitut', 'ememi', 'chirstian', 'street', 'franc', 'deserv', 'laugh', 'feral', 'intergr', 'typic', 'mugshot', 'bother', 'stop', 'mooch', 'hord', 'asian', 'ground', 'nightmar', 'kneegrow', 'patholog', 'overtim', 'subvers', 'aggress', 'faggotri', 'interraci', 'pole', 'swedish', 'holahoax', 'chanc', 'offend', 'coke', 'biblic', 'brussel', 'deal', 'third', 'serious', 'subhuman', 'sort', 'robabl', 'cheat', 'brainwash', 'sharpen', 'chines', 'retak', 'mesico', 'punch', 'continu', 'beaner', 'survivor', 'mobil', 'proncip', 'suffer', 'communist', 'drug', 'justic', 'tummi', 'pavement', 'piec', 'jude', 'dump', 'globe', 'dyke', 'basebal', 'pedophilia', 'kike', 'capitalist', 'tire', 'massiv', 'theyr', 'ghlight', 'earth', 'preacher', 'segreg', 'torch', 'vicori', 'pase', 'romania', 'hate', 'demand', 'iraqi', 'somehow', 'mothergrinninbird', 'garag', 'winnipeg', 'treason', 'combin', 'mushroom', 'steal', 'spew', 'firebird', 'countri', 'immigr', 'dead', 'control', 'nerv', 'undoubtedli', 'head', 'surviv', 'usuali', 'emblem', 'bombs', 'madick', 'serv', 'sloppi', 'denmark', 'modern', 'rohawa', 'cabbag', 'incompet', 'insid', 'parasit', 'sent', 'allow', 'lack', 'faem', 'remind', 'blind', 'heartless', 'fellow', 'everyon', 'wherein', 'kibbl', 'brain', 'nauseum', 'condemn', 'mexico', 'unless', 'passport', 'intellectu', 'cant', 'rapist', 'florida', 'reserv', 'garbag', 'unbear', 'decim', 'stand', 'pose', 'mudslum', 'restor', 'better', 'accommonad', 'ratm', 'darker', 'buri', 'soak', 'femal', 'when', 'marriag', 'openli', 'swim', 'punish', 'slang', 'juden', 'immedi', 'swerv', 'skyyjohn', 'establishedmen', 'agenda', 'cirurgi', 'farkin', 'afreaka', 'hous', 'grab', 'antarctica', 'miseri', 'bugchas', 'occup', 'mutil', 'filipina', 'spit', 'arrest', 'murder', 'playing', 'paso', 'charm', 'stole', 'proffesion', 'basic', 'mango', 'coconut', 'crumbl', 'soil', 'fair', 'race', 'these', 'burn', 'faith', 'domin', 'strip', 'varieti', 'oslo', 'vagina', 'simian', 'regal', 'actress', 'spoken', 'poor', 'downplay', 'aught', 'behind', 'oxygen', 'divers', 'turd', 'prreacher', 'baboon', 'fighter', 'rais', 'idiot', 'congress', 'perform', 'offer', 'apel', 'seper', 'arkansa', 'benefit', 'fals', 'pitch', ' ...
# 2145

# %%
# for x in importance['bottom']:
#   print(x)

# %%
def plot_important_words(top_scores, top_words, bottom_scores, bottom_words, title):
    y_pos = np.arange(len(top_words))
    top_pairs = [(a,b) for a,b in zip(top_words, top_scores)]
    top_pairs = sorted(top_pairs, key=lambda x: x[1])
    
    bottom_pairs = [(a,b) for a,b in zip(bottom_words, bottom_scores)]
    bottom_pairs = sorted(bottom_pairs, key=lambda x: x[1], reverse=True)
    
    top_words = [a[0] for a in top_pairs]
    top_scores = [a[1] for a in top_pairs]
    
    bottom_words = [a[0] for a in bottom_pairs]
    bottom_scores = [a[1] for a in bottom_pairs]
    
    fig = plt.figure(figsize=(10, 10))  
    
    # plot words with most negative coefficients (irrelevant words)
    plt.subplot(121)
    plt.barh(y_pos,bottom_scores, align='center', alpha=0.5)
    plt.title('Hate', fontsize=20)
    plt.yticks(y_pos, bottom_words, fontsize=14)
    plt.suptitle('Key words', fontsize=16)
    plt.xlabel('Importance', fontsize=20)
    #plt.xlim(-8,0)
    
    # plot words with highest coefficients (relevant/disaster words)
    plt.subplot(122)
    plt.barh(y_pos,top_scores, align='center', alpha=0.5)
    plt.title('No_Hate', fontsize=20)
    plt.yticks(y_pos, top_words, fontsize=14)
    plt.suptitle(title, fontsize=16)
    plt.xlabel('Importance', fontsize=20)
    #plt.xlim(0,8)
    
    plt.subplots_adjust(wspace=0.8)
    plt.show()

top_scores = [word_score[0] for word_score in importance['top']]
top_words = [word_score[1] for word_score in importance['top']]
bottom_scores = [word_score[0] for word_score in importance['bottom']]
bottom_words = [word_score[1] for word_score in importance['bottom']]

plot_important_words(top_scores, top_words, bottom_scores, bottom_words, "Most Important (highest coefficient) Words")
