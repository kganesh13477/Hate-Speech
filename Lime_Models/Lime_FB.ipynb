# %%
import keras
import nltk
import pandas as pd
import numpy as np
import re
import io
import matplotlib
from IPython.display import display
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
tweets = pd.read_csv('/content/people.csv')
tweets['gold_hate'] = tweets['gold_hate'].replace({"['hateful']": 0})
tweets['gold_hate'] = tweets['gold_hate'].replace({"['not_hateful']": 1})
dicti = { 'gold_hate': 'class','text': 'tweet'}
tweets.rename(columns=dicti,
          inplace=True)
tweets.head()
# Out:
#       id set_name            img  \
# 0  42953    train  img/42953.png
# 1  23058    train  img/23058.png
# 2  13894    train  img/13894.png
# 3  37408    train  img/37408.png
# 4  82403    train  img/82403.png
#
#                                                tweet  class       gold_pc  \
# 0   its their character not their color that matters      1  ['pc_empty']
# 1  don't be afraid to love again everyone is not ...      1  ['pc_empty']
# 2                           putting bows on your pet      1  ['pc_empty']
# 3  i love everything and everybody! except for sq...      1  ['pc_empty']
# 4  everybody loves chocolate chip cookies, even h...      1  ['pc_empty']
#
#         gold_attack    pc attack
# 0  ['attack_empty']  None   None
# 1  ['attack_empty']  None   None
# 2  ['attack_empty']  None   None
# 3  ['attack_empty']  None   None
# 4  ['attack_empty']  None   None

# %%
# tweets = pd.read_csv("/content/labeled_data.csv")
# tweets['class'] = tweets['class'].replace({2: 1})
# display(tweets.head())
display(tweets.groupby("class").count())
# Out:
#          id  set_name   img  tweet  gold_pc  gold_attack    pc  attack
# class
# 0      3007      3007  3007   3007     3007         3007  3007    3007
# 1      5493      5493  5493   5493     5493         5493  5493    5493

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
nltk.download('punkt')
ps = PorterStemmer()
for i in range(len(tweets)):
  words = word_tokenize(tweets['tweet'][i])
  for j in range(len(words)):
    words[j] = ps.stem(words[j]) if words[j] not in set(all_stopwords) else ''
  tweets['tweet'][i] = ' '.join(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
display(tweets.head())
# Out:
#       id set_name            img  \
# 0  42953    train  img/42953.png
# 1  23058    train  img/23058.png
# 2  13894    train  img/13894.png
# 3  37408    train  img/37408.png
# 4  82403    train  img/82403.png
#
#                                                tweet  class       gold_pc  \
# 0                         charact not  color  matter      1  ['pc_empty']
# 1           n't  afraid  love  everyon  not like  ex      1  ['pc_empty']
# 2                                      put bow   pet      1  ['pc_empty']
# 3   love everyth  everybodi ! except  squirrel  h...      1  ['pc_empty']
# 4     everybodi love chocol chip cooki , even hitler      1  ['pc_empty']
#
#         gold_attack    pc attack
# 0  ['attack_empty']  None   None
# 1  ['attack_empty']  None   None
# 2  ['attack_empty']  None   None
# 3  ['attack_empty']  None   None
# 4  ['attack_empty']  None   None

# %%
def clean_text(df, text_field):
    df[text_field] = df[text_field].str.replace(r"http\S+", "") # remove URL protocol with trailing whitespace
    df[text_field] = df[text_field].str.replace(r"http", "") # remove URL protocol
    df[text_field] = df[text_field].str.replace(r"@\S+", "") # remove at signs with leading spaces 
    df[text_field] = df[text_field].str.replace(r"[^A-Za-z0-9(),!?@\'\`\"\n]", " ") # remove non-alphanumerical
    df[text_field] = df[text_field].str.replace(r"@", "at") # replace at signs with "at"
    df[text_field] = df[text_field].str.replace(r'\b\w{1,3}\b', '') # replace at words
    df[text_field] = df[text_field].str.replace(r'[0-9]', '') # replace at words
    df[text_field] = df[text_field].str.lower() # convert all to lowercase
    # df[text_field] = df[text_field].apply(lambda x: ''.join([stemmer.stem(y) for y in x]))
    return df

# %%
# from nltk.stem import PorterStemmer
# from nltk.tokenize import word_tokenize
# w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
# lemmatizer = nltk.stem.WordNetLemmatizer()
# nltk.download('wordnet')
# nltk.download('omw-1.4')
# ps = PorterStemmer()
# def cleann(df,text_field):
#   df[text_field] = df[text_field].apply(lambda x: ''.join([ps.stem(y) for y in x]))
#   # xp = pd.DataFrame(df[text_field], columns=[text_field])
#   # df[text_field] = xp.text_field.apply([lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text_field)])
#   return df

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# function to transform tweets to vectorized bag of word embedding
def vectorizer(data):
    count_vectorizer = CountVectorizer()

    emb = count_vectorizer.fit_transform(data)

    return emb, count_vectorizer

# set of all tweet text
# list_corpus = tweets["tweet"]
list_corpus = tweets[['class', 'tweet']]
# set of all tweet class labels
list_labels = tweets["class"].tolist()

# split into 80/20 train/test 
X_train, X_test, y_train, y_test = train_test_split(list_corpus, list_labels, test_size=0.2, random_state=69)

X_train = clean_text(X_train, "tweet")
# print(X_train)
# # X_train = cleann(X_train,'tweet')
# print(X_train)

# convert training and test set word to bag of words vectorized representation
X_train_counts, count_vectorizer = vectorizer(X_train['tweet'])
X_test_counts = count_vectorizer.transform(X_test['tweet'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
from sklearn.linear_model import LogisticRegression

# define logistic regression model 
clf = LogisticRegression()

# fit model on training data
clf.fit(X_train_counts, y_train)

# get model predictions on bag of words vectorized test data
y_predicted_counts = clf.predict(X_test_counts)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred_np = clf.predict(X_test_counts)
cm = confusion_matrix(y_test, y_pred_np)
print(classification_report(y_test,y_pred_np))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.45      0.52       586
#            1       0.75      0.86      0.80      1114
#
#     accuracy                           0.72      1700
#    macro avg       0.69      0.65      0.66      1700
# weighted avg       0.71      0.72      0.70      1700

# %%
def get_most_important_features(vectorizer, coefficients, n=20):
    
    # convert index of word from vectorizer into the word 
    index_to_word = {index:word for word,index in count_vectorizer.vocabulary_.items()}
    
    # assign coefficient to word by matching the index of the coefficient and word
    word_importances = [(coef, index_to_word[index]) for index, coef in enumerate(clf.coef_[0])]
    sorted_coeff = sorted(word_importances, key = lambda x : x[0], reverse=True)
    # n = len(word_importances)//2
    # print(word_importances)
    p = []
    n = 0
    for x,y in sorted_coeff:
      if(x>=0):
        n+=1
      p.append(y)
    print(p)
    print(n)
    top = sorted(sorted_coeff[:20], key = lambda x : x)
    print(sorted_coeff[:n])
    print([y for x,y in sorted_coeff[:n]])

    print(len(set(word_importances)))
    bottom = sorted_coeff[-20:]
    print(sorted_coeff[n:])
    p= [y for x,y in sorted_coeff[n:]]
    print(p[::-1])
    print(len(p))
    classes = {
        'top':top,
        'bottom':bottom
        }
    return classes

importance = get_most_important_features(count_vectorizer, clf.coef_)
# Out:
# ['christchurch', 'rebuilt', 'automat', 'rock', 'becam', 'challeng', 'briefcas', 'enter', 'brutal', 'record', 'ball', 'span', 'consid', 'circa', 'self', 'democrat', 'predominantli', 'orang', 'confus', 'fight', 'everyrodi', 'candl', 'wast', 'team', 'photo', 'almost', 'cowboy', 'ignor', 'klan', 'phone', 'drunk', 'improv', 'involv', 'enjoy', 'clinton', 'sinc', 'envis', 'asshol', 'strip', 'club', 'cross', 'store', 'readi', 'fraud', 'wake', 'isnt', 'meanwhil', 'truth', 'cute', 'matt', 'bacon', 'taco', 'snack', 'cult', 'offer', 'masturb', 'explain', 'hillari', 'pictur', 'offici', 'rang', 'follow', 'video', 'chicago', 'chop', 'gloss', 'three', 'pant', 'blew', 'moment', 'divid', 'young', 'block', 'anymor', 'groceri', 'hors', 'basic', 'armi', 'doorway', 'chill', 'beard', 'threaten', 'hair', 'smile', 'danc', 'elizabeth', 'snow', 'condemn', 'assum', 'prayer', 'anybodi', 'crematorium', 'belief', 'save', 'children', 'folk', 'seriou', 'knew', 'bodi', 'summer', 'soldier', 'order', 'ford', 'test', 'statu', 'lunch', 'pleas', 'reason', 'veil', 'worn', 'alright', 'cook', 'older', 'stronger', 'blue', 'simpli', 'movement', 'oldier', 'snort', 'suddenli', 'bless', 'sanctuari', 'meme', 'post', 'heart', 'ladi', 'wayment', 'defend', 'either', 'starv', 'everyth', 'room', 'afford', 'grandma', 'aushwitz', 'solviet', 'turkey', 'mistreat', 'safe', 'arent', 'side', 'beauti', 'evid', 'nation', 'often', 'recip', 'commi', 'nintendo', 'togeth', 'wetern', 'hater', 'sleep', 'barack', 'brick', 'drink', 'newest', 'commit', 'weed', 'london', 'winter', 'perk', 'parent', 'damn', 'privileg', 'gallow', 'heighten', 'less', 'snowflak', 'choke', 'ring', 'bachelor', 'goal', 'austrailia', 'communist', 'amus', 'attitud', 'tini', 'convert', 'anti', 'dysphoria', 'gave', 'pope', 'bull', 'includ', 'patriot', 'shark', 'someon', 'buri', 'interview', 'continu', 'billion', 'imma', 'realiz', 'omar', 'patienc', 'around', 'stamp', 'admit', 'cannabi', 'case', 'selfi', 'bartend', 'declin', 'california', 'baboon', 'juan', 'requir', 'shape', 'gari', 'condom', 'peoppl', 'heaven', 'yoga', 'burger', 'grey', 'litter', 'vitiligo', 'roof', 'properti', 'joke', 'metal', 'return', 'partner', 'jail', 'trump', 'squirter', 'page', 'watch', 'huge', 'squirt', 'pancreat', 'grown', 'text', 'teenag', 'preciou', 'candi', 'brought', 'speak', 'earli', 'stare', 'rohingya', 'invest', 'anjem', 'choudari', 'swim', 'obviou', 'constitut', 'gain', 'weak', 'messeng', 'import', 'summari', 'welcom', 'catch', 'zone', 'buchenwald', 'warrior', 'mandatori', 'equal', 'support', 'slut', 'bird', 'protest', 'yellow', 'sometim', 'everey', 'weekend', 'protect', 'accident', 'express', 'birthday', 'event', 'prevent', 'poke', 'melt', 'traffic', 'vegan', 'bullshit', 'bulli', 'critic', 'meet', 'south', 'senat', 'implant', 'coward', 'slap', 'email', 'mayor', 'golden', 'major', 'rocket', 'honey', 'full', 'slander', 'splendid', 'camper', 'bead', 'prematurley', 'glue', 'silenc', 'investig', 'societi', 'mobil', 'music', 'imag', 'late', 'jannah', 'station', 'chelsea', 'bologna', 'hookah', 'typic', 'manag', 'doll', 'prospect', 'coverag', 'violenc', 'breath', 'employ', 'imprison', 'attack', 'flour', 'seashel', 'thigh', 'basketbal', 'dash', 'auchschwitz', 'rath', 'cheeseburg', 'bust', 'wink', 'wizard', 'though', 'politician', 'sexual', 'claim', 'bottom', 'passeng', 'surgeri', 'dummi', 'filter', 'combin', 'reac', 'chart', 'dulux', 'crazi', 'seen', 'patti', 'feel', 'wore', 'chosen', 'weird', 'panti', 'help', 'friday', 'sens', 'prize', 'reciev', 'shitti', 'apolog', 'agent', 'whatev', 'russian', 'hussein', 'throat', 'tomboyish', 'threat', 'mind', 'hobbi', 'depress', 'check', 'inelig', 'cake', 'belli', 'capit', 'base', 'guid', 'tampon', 'bloodi', 'built', 'cannon', 'yeet', 'grenad', 'clean', 'duke', 'fractur', 'mayo', 'film', 'cancel', 'blacken', 'longer', 'trial', 'stranger', 'next', 'nonsens', 'unconvent', 'therapi', 'fallonfox', 'transgenderman', 'poster', 'theleft', 'stir', 'control', 'dryer', 'whose', 'jizz', 'mchitler', 'delici', 'sasha', 'spac ...
# 2921
# [(1.8757247706235831, 'christchurch'), (1.3590904453817905, 'rebuilt'), (1.3285961542591707, 'automat'), (1.2813910065513647, 'rock'), (1.2712665597616097, 'becam'), (1.2308771554537015, 'challeng'), (1.136817601203178, 'briefcas'), (1.1274655815350696, 'enter'), (1.107497765972367, 'brutal'), (1.0611742810672213, 'record'), (1.053483472306232, 'ball'), (1.0480468135856573, 'span'), (1.0383529084864034, 'consid'), (1.0262097486854418, 'circa'), (1.0165126887442733, 'self'), (1.0006715550952465, 'democrat'), (0.9768790269897346, 'predominantli'), (0.9628047138376511, 'orang'), (0.9561923963209767, 'confus'), (0.9524328471161541, 'fight'), (0.9395305382702663, 'everyrodi'), (0.9318538854994671, 'candl'), (0.9317417542067267, 'wast'), (0.9270097708445593, 'team'), (0.9165368581734786, 'photo'), (0.9137042141287586, 'almost'), (0.8984124950887948, 'cowboy'), (0.8903779743832201, 'ignor'), (0.889750123278877, 'klan'), (0.8751114299152277, 'phone'), (0.8545976996526033, 'drunk'), (0.8475300207058861, 'improv'), (0.8459370653714897, 'involv'), (0.8385449188323576, 'enjoy'), (0.8381365136412525, 'clinton'), (0.8371947535351603, 'sinc'), (0.8318155333926213, 'envis'), (0.8225864927055954, 'asshol'), (0.8194152825847353, 'strip'), (0.8076387060573942, 'club'), (0.8060358465413547, 'cross'), (0.802961367940981, 'store'), (0.7993391330894791, 'readi'), (0.7981022647869305, 'fraud'), (0.7923900661631506, 'wake'), (0.7910209381566233, 'isnt'), (0.7896612314225537, 'meanwhil'), (0.7890438417360531, 'truth'), (0.7862741558533854, 'cute'), (0.7861203864786497, 'matt'), (0.7825772531244933, 'bacon'), (0.7811502491961214, 'taco'), (0.7806954222392662, 'snack'), (0.7796650942030359, 'cult'), (0.7791968341650122, 'offer'), (0.7779377373444654, 'masturb'), (0.7767052301913074, 'explain'), (0.7741959355331888, 'hillari'), (0.7705876931021828, 'pictur'), (0.7669781635322113, 'offici'), (0.7628834101617445, 'rang'), (0.762224158306117, 'follow'), (0.7553312185036369, 'video'), (0.7544798576983105, 'chicago'), (0.74826494397967, 'chop'), (0.747146922727233, 'gloss'), (0.738836449642853, 'three'), (0.7338004084530507, 'pant'), (0.7302691502134979, 'blew'), (0.7294960054186653, 'moment'), (0.7294928669355274, 'divid'), (0.7266336847167058, 'young'), (0.722178608158211, 'block'), (0.722119232081877, 'anymor'), (0.7207338603883007, 'groceri'), (0.7205503291261773, 'hors'), (0.720298908225413, 'basic'), (0.7186865661993004, 'armi'), (0.7164060800897044, 'doorway'), (0.7139282675419163, 'chill'), (0.713668083425011, 'beard'), (0.7094132969613569, 'threaten'), (0.7084902415773915, 'hair'), (0.7057684874309332, 'smile'), (0.7030747591060129, 'danc'), (0.7022884194975962, 'elizabeth'), (0.7016782415794693, 'snow'), (0.6961836345851785, 'condemn'), (0.6944252935153631, 'assum'), (0.6939509624423118, 'prayer'), (0.6881618426270454, 'anybodi'), (0.686130592481205, 'crematorium'), (0.6847209532587513, 'belief'), (0.6819560413121601, 'save'), (0.6795189360501888, 'children'), (0.6795012846081764, 'folk'), (0.6790506913677186, 'seriou'), (0.6782754615787489, 'knew'), (0.6782163506405526, 'bodi'), (0.6764662766756014, 'summer'), (0.6742332650478227, 'soldier'), (0.6720828633622442, 'order'), (0.6714388111886753, 'ford'), (0.6712607928614752, 'test'), (0.6711285595168937, 'statu'), (0.6696884512932096, 'lunch'), (0.669484000931522, 'pleas'), (0.6686004309549173, 'reason'), (0.6660591098356275, 'veil'), (0.6660591098356275, 'worn'), (0.6600102420834881, 'alright'), (0.6503350644537836, 'cook'), (0.6501936614576238, 'older'), (0.6483806101324849, 'stronger'), (0.6476008934470702, 'blue'), (0.6445494349636356, 'simpli'), (0.6435011893819506, 'movement'), (0.6406892414908153, 'oldier'), (0.6406443541865197, 'snort'), (0.6400962685579397, 'suddenli'), (0.6390358672041784, 'bless'), (0.6386981391938706, 'sanctuari'), (0.6357682436546845, 'meme'), (0.6334804666189204, 'post'), (0.6314309808079672, 'heart'), (0.6303118671204521, 'ladi'), (0.6284343682420294, 'wayment'), (0.626 ...
# ['christchurch', 'rebuilt', 'automat', 'rock', 'becam', 'challeng', 'briefcas', 'enter', 'brutal', 'record', 'ball', 'span', 'consid', 'circa', 'self', 'democrat', 'predominantli', 'orang', 'confus', 'fight', 'everyrodi', 'candl', 'wast', 'team', 'photo', 'almost', 'cowboy', 'ignor', 'klan', 'phone', 'drunk', 'improv', 'involv', 'enjoy', 'clinton', 'sinc', 'envis', 'asshol', 'strip', 'club', 'cross', 'store', 'readi', 'fraud', 'wake', 'isnt', 'meanwhil', 'truth', 'cute', 'matt', 'bacon', 'taco', 'snack', 'cult', 'offer', 'masturb', 'explain', 'hillari', 'pictur', 'offici', 'rang', 'follow', 'video', 'chicago', 'chop', 'gloss', 'three', 'pant', 'blew', 'moment', 'divid', 'young', 'block', 'anymor', 'groceri', 'hors', 'basic', 'armi', 'doorway', 'chill', 'beard', 'threaten', 'hair', 'smile', 'danc', 'elizabeth', 'snow', 'condemn', 'assum', 'prayer', 'anybodi', 'crematorium', 'belief', 'save', 'children', 'folk', 'seriou', 'knew', 'bodi', 'summer', 'soldier', 'order', 'ford', 'test', 'statu', 'lunch', 'pleas', 'reason', 'veil', 'worn', 'alright', 'cook', 'older', 'stronger', 'blue', 'simpli', 'movement', 'oldier', 'snort', 'suddenli', 'bless', 'sanctuari', 'meme', 'post', 'heart', 'ladi', 'wayment', 'defend', 'either', 'starv', 'everyth', 'room', 'afford', 'grandma', 'aushwitz', 'solviet', 'turkey', 'mistreat', 'safe', 'arent', 'side', 'beauti', 'evid', 'nation', 'often', 'recip', 'commi', 'nintendo', 'togeth', 'wetern', 'hater', 'sleep', 'barack', 'brick', 'drink', 'newest', 'commit', 'weed', 'london', 'winter', 'perk', 'parent', 'damn', 'privileg', 'gallow', 'heighten', 'less', 'snowflak', 'choke', 'ring', 'bachelor', 'goal', 'austrailia', 'communist', 'amus', 'attitud', 'tini', 'convert', 'anti', 'dysphoria', 'gave', 'pope', 'bull', 'includ', 'patriot', 'shark', 'someon', 'buri', 'interview', 'continu', 'billion', 'imma', 'realiz', 'omar', 'patienc', 'around', 'stamp', 'admit', 'cannabi', 'case', 'selfi', 'bartend', 'declin', 'california', 'baboon', 'juan', 'requir', 'shape', 'gari', 'condom', 'peoppl', 'heaven', 'yoga', 'burger', 'grey', 'litter', 'vitiligo', 'roof', 'properti', 'joke', 'metal', 'return', 'partner', 'jail', 'trump', 'squirter', 'page', 'watch', 'huge', 'squirt', 'pancreat', 'grown', 'text', 'teenag', 'preciou', 'candi', 'brought', 'speak', 'earli', 'stare', 'rohingya', 'invest', 'anjem', 'choudari', 'swim', 'obviou', 'constitut', 'gain', 'weak', 'messeng', 'import', 'summari', 'welcom', 'catch', 'zone', 'buchenwald', 'warrior', 'mandatori', 'equal', 'support', 'slut', 'bird', 'protest', 'yellow', 'sometim', 'everey', 'weekend', 'protect', 'accident', 'express', 'birthday', 'event', 'prevent', 'poke', 'melt', 'traffic', 'vegan', 'bullshit', 'bulli', 'critic', 'meet', 'south', 'senat', 'implant', 'coward', 'slap', 'email', 'mayor', 'golden', 'major', 'rocket', 'honey', 'full', 'slander', 'splendid', 'camper', 'bead', 'prematurley', 'glue', 'silenc', 'investig', 'societi', 'mobil', 'music', 'imag', 'late', 'jannah', 'station', 'chelsea', 'bologna', 'hookah', 'typic', 'manag', 'doll', 'prospect', 'coverag', 'violenc', 'breath', 'employ', 'imprison', 'attack', 'flour', 'seashel', 'thigh', 'basketbal', 'dash', 'auchschwitz', 'rath', 'cheeseburg', 'bust', 'wink', 'wizard', 'though', 'politician', 'sexual', 'claim', 'bottom', 'passeng', 'surgeri', 'dummi', 'filter', 'combin', 'reac', 'chart', 'dulux', 'crazi', 'seen', 'patti', 'feel', 'wore', 'chosen', 'weird', 'panti', 'help', 'friday', 'sens', 'prize', 'reciev', 'shitti', 'apolog', 'agent', 'whatev', 'russian', 'hussein', 'throat', 'tomboyish', 'threat', 'mind', 'hobbi', 'depress', 'check', 'inelig', 'cake', 'belli', 'capit', 'base', 'guid', 'tampon', 'bloodi', 'built', 'cannon', 'yeet', 'grenad', 'clean', 'duke', 'fractur', 'mayo', 'film', 'cancel', 'blacken', 'longer', 'trial', 'stranger', 'next', 'nonsens', 'unconvent', 'therapi', 'fallonfox', 'transgenderman', 'poster', 'theleft', 'stir', 'control', 'dryer', 'whose', 'jizz', 'mchitler', 'delici', 'sasha', 'spac ...
# 5276
# [(-2.3152217483334054e-05, 'assassin'), (-0.00014339688829800236, 'prostat'), (-0.0005093751840042823, 'sniffer'), (-0.0010286255805110748, 'heritag'), (-0.0010286255805110748, 'realist'), (-0.0010286255805110748, 'secondari'), (-0.0011295291604465074, 'sunday'), (-0.0015675334842482666, 'bowl'), (-0.0017275439282427756, 'serial'), (-0.0017392479184458619, 'multipl'), (-0.001872298774191126, 'walmart'), (-0.002095176546488437, 'dollar'), (-0.00213091696243464, 'jewsi'), (-0.0025865460739293348, 'brotherhood'), (-0.002880731557707677, 'centr'), (-0.002880731557707677, 'dawah'), (-0.002880731557707677, 'electr'), (-0.002880731557707677, 'generos'), (-0.002880731557707677, 'graditud'), (-0.002880731557707677, 'refug'), (-0.002880731557707677, 'stall'), (-0.003138805747106502, 'slowli'), (-0.0045101724608237635, 'radiu'), (-0.004789358666231635, 'homeland'), (-0.004883070966629687, 'habbo'), (-0.005042734513551277, 'lobbi'), (-0.00514350320687591, 'pervert'), (-0.0073932966652257405, 'crap'), (-0.007907701040640192, 'river'), (-0.008093653836750668, 'point'), (-0.008738419891096841, 'mexico'), (-0.009316294261242032, 'hard'), (-0.00992540047089083, 'conclus'), (-0.010633017855486548, 'nuke'), (-0.010709625510907345, 'bound'), (-0.01091184076518007, 'pronoun'), (-0.010936951062905542, 'home'), (-0.011125184482579575, 'enough'), (-0.011462568775946522, 'fool'), (-0.011549730470524362, 'mccain'), (-0.01163072576566841, 'survey'), (-0.01167686252413747, 'saria'), (-0.011809355306727784, 'footag'), (-0.012219298954217722, 'fetu'), (-0.012258478553485195, 'farm'), (-0.012595071394170553, 'cocain'), (-0.01282473413276645, 'minut'), (-0.012932452844565047, 'consruct'), (-0.012932452844565047, 'feminin'), (-0.013212398350726025, 'templat'), (-0.013219899797098492, 'healthcar'), (-0.013593477312843992, 'truck'), (-0.013767497972471471, 'polici'), (-0.013960350041944935, 'unfollow'), (-0.015250132950540804, 'uncook'), (-0.016018856897389976, 'scholar'), (-0.016257472357112553, 'color'), (-0.01628986766132495, 'meathead'), (-0.016513368262052366, 'pedal'), (-0.01657640507683488, 'fucker'), (-0.017023606554916033, 'humour'), (-0.01730291845883991, 'band'), (-0.017906528440506893, 'seiz'), (-0.01820529583206928, 'terribl'), (-0.018533097960128607, 'trip'), (-0.01875681812704923, 'cotton'), (-0.01895874442164179, 'someth'), (-0.01951152011948987, 'bottl'), (-0.02012652793132465, 'captur'), (-0.02035266221594801, 'explos'), (-0.020527177033145, 'legal'), (-0.02054757070256901, 'trust'), (-0.020880823816876667, 'crop'), (-0.021024458892215728, 'realli'), (-0.02122712266997322, 'jamaican'), (-0.021323402346805086, 'stabl'), (-0.02223174368036941, 'lucki'), (-0.02228311143473214, 'leash'), (-0.022372036498861252, 'birth'), (-0.02270734971816851, 'pimp'), (-0.02309950410977425, 'fertil'), (-0.023429940875556603, 'player'), (-0.02350270862705308, 'round'), (-0.023642025344500214, 'complain'), (-0.023751981039578367, 'nasa'), (-0.024461430331599268, 'eventu'), (-0.024856816929372878, 'sandi'), (-0.02532178027104842, 'daili'), (-0.0255435896253814, 'permiss'), (-0.02555606807084767, 'boot'), (-0.026167019264213456, 'respons'), (-0.026292390028793976, 'interraci'), (-0.026379220498598564, 'calm'), (-0.026448350999617787, 'unbreak'), (-0.0265460918263116, 'fanat'), (-0.026778250834585085, 'stair'), (-0.026879441443845763, 'estat'), (-0.027318769629303085, 'nuclear'), (-0.027884652064261866, 'facebook'), (-0.028183907376132005, 'commun'), (-0.028397044185155467, 'creatur'), (-0.02841558233407222, 'breeder'), (-0.02841558233407222, 'paedophilia'), (-0.02841558233407222, 'unwelcom'), (-0.028509196209968692, 'atlant'), (-0.030029772193614874, 'behaviour'), (-0.03007704107016993, 'burnt'), (-0.030142589682172545, 'euthanasia'), (-0.030142589682172545, 'harvard'), (-0.030142589682172545, 'lmfao'), (-0.03016648586734781, 'christ'), (-0.03019325353400423, 'flat'), (-0.031195684051670943, 'establish'), (-0.03128266050516586, 'ship'), (-0.03142531948754918, 'mushro ...
# ['nigger', 'retard', 'faggot', 'transgend', 'tranni', 'asian', 'mexican', 'black', 'muslim', 'islam', 'tran', 'diaper', 'oven', 'dead', 'queer', 'erni', 'peni', 'holocaust', 'zionist', 'homosexu', 'jewish', 'latino', 'etern', 'women', 'dark', 'pride', 'white', 'deport', 'comment', 'islamaphob', 'midget', 'jihad', 'niether', 'voter', 'plane', 'gender', 'autism', 'europ', 'down', 'arab', 'chamber', 'africa', 'behead', 'virgin', 'dishwash', 'jolo', 'rapist', 'moham', 'teach', 'ethiopian', 'slave', 'extermin', 'colour', 'slaveri', 'gnigger', 'list', 'akbar', 'abdul', 'later', 'cracka', 'north', 'stolen', 'frankli', 'infidel', 'autist', 'cooker', 'cours', 'nibba', 'refuge', 'israel', 'dike', 'auschwitz', 'word', 'marokko', 'mosqu', 'gamer', 'subway', 'concentr', 'grandpa', 'suicid', 'devil', 'arnold', 'spook', 'nagger', 'woman', 'normal', 'bang', 'evolv', 'camp', 'fondl', 'accept', 'blow', 'mental', 'snap', 'contri', 'bastard', 'port', 'rape', 'hate', 'chong', 'ching', 'lgbt', 'prove', 'yard', 'allah', 'steal', 'somewher', 'faster', 'isra', 'thousand', 'minesweep', 'syndrom', 'behind', 'goatfuck', 'blind', 'lynn', 'brain', 'handbook', 'invad', 'harri', 'grandfath', 'juic', 'sandwich', 'classroom', 'scum', 'resid', 'balconi', 'your', 'monkey', 'chicken', 'infiltr', 'hijack', 'moslem', 'driver', 'male', 'todd', 'retodd', 'hockey', 'violent', 'muhammad', 'penni', 'seizur', 'wors', 'chromosom', 'stone', 'august', 'menu', 'bomb', 'refer', 'storm', 'porkistan', 'unclean', 'hebrew', 'center', 'indian', 'stole', 'crakkka', 'fuel', 'trade', 'singl', 'palestinian', 'adopt', 'role', 'islamist', 'chemic', 'extinct', 'whiteman', 'lost', 'handicap', 'abomin', 'squad', 'wipe', 'germani', 'muham', 'lesbian', 'blowin', 'patrick', 'nevermind', 'burn', 'instructor', 'tighten', 'hide', 'seuss', 'explod', 'forgotten', 'chines', 'habibi', 'femin', 'upset', 'disarm', 'purchas', 'pick', 'tranpa', 'spastic', 'invit', 'backward', 'gorilla', 'bruce', 'kick', 'blowjob', 'piano', 'mommi', 'gettin', 'pm', 'goofi', 'medium', 'chemo', 'floor', 'head', 'special', 'intent', 'horni', 'innoc', 'womb', 'prepar', 'danger', 'race', 'mosquito', 'cant', 'literatur', 'cookbook', 'academi', 'clue', 'sharia', 'microwav', 'throw', 'hotlin', 'erad', 'downtown', 'anywher', 'work', 'winner', 'yeah', 'hunger', 'faceswap', 'screen', 'breed', 'guard', 'deep', 'kill', 'chickin', 'korea', 'plantat', 'equip', 'tractor', 'woof', 'ramit', 'inmah', 'ashol', 'disord', 'remind', 'glass', 'honki', 'whitetrash', 'hoosier', 'born', 'martin', 'technolog', 'twin', 'modern', 'schwitchz', 'cannib', 'marri', 'genocid', 'histoy', 'bigot', 'recognis', 'serbian', 'peinigg', 'fuhreri', 'fuhrereri', 'fleshlight', 'shower', 'that', 'wimpi', 'jesu', 'cinco', 'came', 'handjob', 'mama', 'goyim', 'fruit', 'standard', 'insid', 'farmersownm', 'fault', 'damnit', 'jazz', 'trash', 'favorit', 'threatend', 'shel', 'volk', 'hump', 'pokemon', 'sold', 'niccep', 'femal', 'ohhh', 'decad', 'hung', 'frank', 'ramadan', 'becuas', 'grape', 'pregnant', 'gallon', 'whorefax', 'glori', 'cancer', 'croatia', 'allahbomb', 'tall', 'skinni', 'planet', 'price', 'what', 'ratchet', 'butterfli', 'trigger', 'countrysid', 'slavemast', 'scissor', 'hardest', 'view', 'shouldnt', 'slice', 'heil', 'none', 'homicid', 'name', 'percent', 'basement', 'australia', 'hazzard', 'goat', 'justifi', 'john', 'tattoo', 'export', 'heidi', 'crowter', 'buslim', 'punch', 'flush', 'sammich', 'cape', 'skidmark', 'spacki', 'alabama', 'discrimin', 'mutil', 'arriv', 'tard', 'patriarchi', 'knock', 'appear', 'transphob', 'bihari', 'cock', 'wallet', 'wart', 'doesh', 'anyon', 'deaf', 'michel', 'smell', 'crawl', 'slow', 'poppin', 'islamphob', 'luckili', 'latina', 'wive', 'franken', 'deoder', 'oink', 'brithday', 'circl', 'fake', 'senior', 'methican', 'fact', 'jewelri', 'auburn', 'milkshak', 'reinstat', 'uber', 'taliban', 'bingo', 'social', 'laid', 'siames', 'donkey', 'nakba', 'clamp', 'mooch', 'habit', 'mass', 'yooouu', 'lookah', 'choco', 'locat', 'upper', 'fryyi', 'down ...
# 2355

# %%
# for x in importance['bottom']:
#   print(x)

# %%
def plot_important_words(top_scores, top_words, bottom_scores, bottom_words, title):
    y_pos = np.arange(len(top_words))
    top_pairs = [(a,b) for a,b in zip(top_words, top_scores)]
    top_pairs = sorted(top_pairs, key=lambda x: x[1])
    
    bottom_pairs = [(a,b) for a,b in zip(bottom_words, bottom_scores)]
    bottom_pairs = sorted(bottom_pairs, key=lambda x: x[1], reverse=True)
    
    top_words = [a[0] for a in top_pairs]
    top_scores = [a[1] for a in top_pairs]
    
    bottom_words = [a[0] for a in bottom_pairs]
    bottom_scores = [a[1] for a in bottom_pairs]
    
    fig = plt.figure(figsize=(10, 10))  
    
    # plot words with most negative coefficients (irrelevant words)
    plt.subplot(121)
    plt.barh(y_pos,bottom_scores, align='center', alpha=0.5)
    plt.title('Hate', fontsize=20)
    plt.yticks(y_pos, bottom_words, fontsize=14)
    plt.suptitle('Key words', fontsize=16)
    plt.xlabel('Importance', fontsize=20)
    #plt.xlim(-8,0)
    
    # plot words with highest coefficients (relevant/disaster words)
    plt.subplot(122)
    plt.barh(y_pos,top_scores, align='center', alpha=0.5)
    plt.title('No_Hate', fontsize=20)
    plt.yticks(y_pos, top_words, fontsize=14)
    plt.suptitle(title, fontsize=16)
    plt.xlabel('Importance', fontsize=20)
    #plt.xlim(0,8)
    
    plt.subplots_adjust(wspace=0.8)
    plt.show()

top_scores = [word_score[0] for word_score in importance['top']]
top_words = [word_score[1] for word_score in importance['top']]
bottom_scores = [word_score[0] for word_score in importance['bottom']]
bottom_words = [word_score[1] for word_score in importance['bottom']]

plot_important_words(top_scores, top_words, bottom_scores, bottom_words, "Most Important (highest coefficient) Words")
